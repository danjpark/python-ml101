# %%
from bokeh.io import output_notebook, show
from bokeh.plotting import figure

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="377ed1b6-be1d-4386-b4d8-2c322bd04f83">Loading BokehJS ...</span>
#     </div>

# %%
# create a new plot with default tools, using figure
p = figure(plot_width=500,
           plot_height=500,
          )

# add a circle renderer with a size, color, and alpha
p.circle([1, 2, 3, 4, 5], [6, 7, 2, 4, 5], size=15, line_color="navy", fill_color="orange", fill_alpha=0.5)

show(p) # show the results
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="19a4cd6a-0c82-47d9-afe3-865527423f34"></div>
# </div>

# %%
# EXERCISE: Try changing the example above to set a `radius` value instead of `size`


# create a new plot with default tools, using figure
p = figure(plot_width=500,
           plot_height=500,
          )

# add a circle renderer with a size, color, and alpha
p.circle([1, 2, 3, 4, 5],
         [6, 7, 2, 4, 5],
         radius=0.5,
         line_color="navy",
         fill_color="orange",
         fill_alpha=0.5)

show(p) # show the results
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="e2250a97-0b73-4ad1-8b7a-dea5199ed0e0"></div>
# </div>

# %%
# create a new plot using figure
p = figure(plot_width=400, plot_height=400)

# add a square renderer with a size, color, alpha, and sizes
p.square([1, 2, 3, 4, 5],
         [6, 7, 2, 4, 5],
         size=[10, 15, 20, 25, 30],
         color="firebrick",
         alpha=0.6)

show(p) # show the results
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="1ddfe607-76f1-4cee-8eff-b3c9e2dc0eae"></div>
# </div>
